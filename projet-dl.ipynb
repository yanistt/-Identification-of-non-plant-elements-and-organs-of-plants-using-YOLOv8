# %%
# !wget https://download.pangaea.de/dataset/920895/files/Dataset.rar

# %%
# !apt-get install -y unrar

# %%
# import os

# # Path to your RAR file
# rar_file_path = '/kaggle/input/annotations-vegetable/Dataset'

# # Destination folder where you want to extract files
# extract_folder = '/kaggle/working/'

# # Create the destination folder if it doesn't exist
# os.makedirs(extract_folder, exist_ok=True)

# # Use the unrar command to extract the RAR file
# os.system(f'unrar x "{rar_file_path}" "{extract_folder}"')

# import zipfile

# def unzip_file(zip_file_path, extract_to_path):
#     with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
#         zip_ref.extractall(extract_to_path)

# # Example usage:
# zip_file_path =  './annotations-vegetable/Dataset'
# extract_to_path = '/kaggle/working/'

# unzip_file(zip_file_path, extract_to_path)

# %%
import matplotlib.pyplot as plt
import cv2

# Load the image using OpenCV
image_path = '/kaggle/input/non-vegetal-annotated-dataset/Non-Vegetal Annotated Dataset/FR-0001310_jpg.rf.0b75d3ecae672324f3310db3206e41e7.jpg'
image = cv2.imread(image_path)

# # Check the data type
# print("Image Data Type:", image.dtype)

# Convert image data to float
image_float = image.astype(float)

# # Display the image
plt.imshow(image)
plt.show()

# %%
# !mv "/kaggle/input/non-vegetal-annotated-dataset/Non-Vegetal Annotated Dataset" Dataset
# Out:
# mv: cannot remove '/kaggle/input/non-vegetal-annotated-dataset/Non-Vegetal Annotated Dataset/FR-0004608_jpg.rf.12ba58584a1af797245f6019c2136cda.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/non-vegetal-annotated-dataset/Non-Vegetal Annotated Dataset/FR-0036374_jpg.rf.8984d2b28cd04672f57a6a4910ca2270.xml': Read-only file system
# mv: cannot remove '/kaggle/input/non-vegetal-annotated-dataset/Non-Vegetal Annotated Dataset/FR-0036341_jpg.rf.64b747fab3239238f178ad29e6a17c06.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/non-vegetal-annotated-dataset/Non-Vegetal Annotated Dataset/FR-0030829_jpg.rf.554d693ce5210676886ad76daaaa26d2.xml': Read-only file system
# mv: cannot remove '/kaggle/input/non-vegetal-annotated-dataset/Non-Vegetal Annotated Dataset/FR-0036368_jpg.rf.47ef31d89ce4e120368f7f34a45c3b77.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/non-vegetal-annotated-dataset/Non-Vegetal Annotated Dataset/FR-0036305_jpg.rf.f82a3abae08eb451e2a1a4bb8fabe4c4.xml': Read-only file system
# mv: cannot remove '/kaggle/input/non-vegetal-annotated-dataset/Non-Vegetal Annotated Dataset/FR-0036386_jpg.rf.a77bf637678a8575caf7aa0469c523cc.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/non-vegetal-annotated-dataset/Non-Vegetal Annotated Dataset/FR-0030845_jpg.rf.6f7640732b70b0f56d0db8abe8ee7004.xml': Read-only file system
# mv: cannot remove '/kaggle/input/non-vegetal-annotated-dataset/Non-Vegetal Annotated Dataset/FR-0007263_jpg.rf.0534e29edb0d6a147c725d287e44eb3c.xml': Read-only file system
# mv: cannot remove '/kaggle/input/non-vegetal-annotated-dataset/Non-Vegetal Annotated Dataset/FR-0036305_jpg.rf.f82a3abae08eb451e2a1a4bb8fabe4c4.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/non-vegetal-annotated-dataset/Non-Vegetal Annotated Dataset/FR-0030802_jpg.rf.f2d0a3a2718f13181cdd8de578ff4536.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/non-vegetal-annotated-dataset/Non-Vegetal Annotated Dataset/FR-0030803_jpg.rf.7286d8cef4bb86f8790d2856227571f0.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/non-vegetal-annotated-dataset/Non-Vegetal Annotated Dataset/FR-0030805_jpg.rf.2ce62de8c32f2bd4023a438ac4c88797.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/non-vegetal-annotated-dataset/Non-Vegetal Annotated Dataset/FR-0036319_jpg.rf.c66539c54aa80064e18aeae4802e8438.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/non-vegetal-annotated-dataset/Non-Vegetal Annotated Dataset/FR-0030813_jpg.rf.7b3ce6a47b63b0b126813edf9a808ec5.xml': Read-only file system
# mv: cannot remove '/kaggle/input/non-vegetal-annotated-dataset/Non-Vegetal Annotated Dataset/FR-0001314_jpg.rf.48bb424a2613522b1ca8a0ce20d5f84a.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/non-vegetal-annotated-dataset/Non-Vegetal Annotated Dataset/FR-0030826_jpg.rf.19ae263d168d7a0cbb7609218617b444.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/non-vegetal-annotated-dataset/Non-Vegetal Annotated Dataset/FR-0030826_jpg.rf.1c52093df4bb91ca5e1010b892d20fa0.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/non-vegetal-annotated-dataset/Non-Vegetal Annotated Dataset/FR-0004455_jpg.rf.35c653b9015d84e891aed43d9cc30860.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/non-vegetal-annotated-dataset/Non-Vegetal Annotated Dataset/FR-0004456_jpg.rf.264726f4a227fae83ed1411c2ff12bd6.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/non-vegetal-annotated-dataset/Non-Vegetal Annotated Dataset/FR-0036347_jpg.rf.d4db9bb0f03163e8bcedfc83ef1e7e7b.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/non-vegetal-annotated-dataset/Non-Vegetal Annotated Dataset/FR-0036327_jpg.rf.affaf58aa5ad31b09f8cfc99f4549e88.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/non-vegetal-annotated-dataset/Non-Vegetal Annotated Dataset/FR-0001318_jpg.rf.22738f259717fb0ed0d73432973e70c5.xml': Read-only file system
# mv: cannot remove '/kaggle/input/non-vegetal-annotated-dataset/Non-Vegetal Annotated Dataset/FR-0030828_jpg.rf.aaac1403a3065d776a7a91c1d8273d8c.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/non-vegetal-annotated-dataset/Non-Vegetal Annotated Dataset/FR-0036327_jpg.rf.bf8eb7a98c695015d5d1e790916bf71e.xml': Read-only file system
# mv: cannot remove '/kaggle/input/non-vegetal-annotated-dataset/Non-Vegetal Annotated Dataset/FR-0030798_jpg.rf.67d3bbf939d24a4054c07f60ae545c92.xml': Read-only file system
# mv: cannot remove '/kaggle/input/non-vegetal-annotated-dataset/Non-Vegetal Annotated Dataset/FR-0030873_jpg.rf.289e1b7cde6f4bab62039680914c1627.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/non-vegetal-annotated-dataset/Non-Vegetal Annotated Dataset/FR-0030904_jpg.rf.2d2ff6c095ae6da4122be2f816269098.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/non-vegetal-annotated-dataset/Non-Vegetal Annotated Dataset/FR-0036385_jpg.rf.729b7918985aa321cf17608cb3f10582.xml': Read-only file system
# mv: cannot remove '/kaggle/input/non-vegetal-annotated-dataset/Non-Vegetal Annotated Dataset/FR-0
jpg': Read-only file system
# mv: cannot remove '/kaggle/input/non-vegetal-annotated-dataset/Non-Vegetal Annotated Dataset/FR-0030857_jpg.rf.b57c895f0e5c04a6dfcdde255b9861aa.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/non-vegetal-annotated-dataset/Non-Vegetal Annotated Dataset/FR-0036362_jpg.rf.4aeed6a9a9356c8b3840d8a259023718.xml': Read-only file system
# mv: cannot remove '/kaggle/input/non-vegetal-annotated-dataset/Non-Vegetal Annotated Dataset/FR-0036310_jpg.rf.d50bdcdbed91a7a1b5846f8420ce57fd.xml': Read-only file system
# mv: cannot remove '/kaggle/input/non-vegetal-annotated-dataset/Non-Vegetal Annotated Dataset/FR-0030821_jpg.rf.726748a2089f78e3bf1322a8838b806e.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/non-vegetal-annotated-dataset/Non-Vegetal Annotated Dataset/FR-0030850_jpg.rf.627904fea2f49cd0e764149dba9b4605.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/non-vegetal-annotated-dataset/Non-Vegetal Annotated Dataset/FR-0030881_jpg.rf.d19d2b8ab87c0880d9343894c26d070b.xml': Read-only file system
# mv: cannot remove '/kaggle/input/non-vegetal-annotated-dataset/Non-Vegetal Annotated Dataset/FR-0030874_jpg.rf.7d95676b23369f192d1f16b338327e92.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/non-vegetal-annotated-dataset/Non-Vegetal Annotated Dataset/FR-0036390_jpg.rf.7ba4cb756d6d9977f0c0bd59b2204ca2.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/non-vegetal-annotated-dataset/Non-Vegetal Annotated Dataset/FR-0030802_jpg.rf.bda1b2f2da3dbe0a3ec5e0b1145a3e78.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/non-vegetal-annotated-dataset/Non-Vegetal Annotated Dataset/FR-0004455_jpg.rf.35c653b9015d84e891aed43d9cc30860.xml': Read-only file system
# mv: cannot remove '/kaggle/input/non-vegetal-annotated-dataset/Non-Vegetal Annotated Dataset/FR-0004619_jpg.rf.55987c41c51e92ab11311ea155c92b91.xml': Read-only file system
# mv: cannot remove '/kaggle/input/non-vegetal-annotated-dataset/Non-Vegetal Annotated Dataset/FR-0030792_jpg.rf.539f14596d5882d8fc046298896d4ebd.xml': Read-only file system
# mv: cannot remove '/kaggle/input/non-vegetal-annotated-dataset/Non-Vegetal Annotated Dataset/FR-0001317_jpg.rf.c877e8c53f491d98f6b590847d445bfd.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/non-vegetal-annotated-dataset/Non-Vegetal Annotated Dataset/FR-0036381_jpg.rf.ec68532f4ffd9536955a5241168d32d1.xml': Read-only file system
# mv: cannot remove '/kaggle/input/non-vegetal-annotated-dataset/Non-Vegetal Annotated Dataset/FR-0036349_jpg.rf.ca3669071b07d5b489c8ff3a80b36c08.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/non-vegetal-annotated-dataset/Non-Vegetal Annotated Dataset/FR-0030854_jpg.rf.a0100f3e4cdb57ac36f32c26b2f2b669.xml': Read-only file system
# mv: cannot remove '/kaggle/input/non-vegetal-annotated-dataset/Non-Vegetal Annotated Dataset/FR-0030909_jpg.rf.66365b4737d258e9c1b1ca05fa036a05.xml': Read-only file system
# mv: cannot remove '/kaggle/input/non-vegetal-annotated-dataset/Non-Vegetal Annotated Dataset/FR-0001319_jpg.rf.0202656b2e85d7ddc19e7471d633a7ab.xml': Read-only file system
# mv: cannot remove '/kaggle/input/non-vegetal-annotated-dataset/Non-Vegetal Annotated Dataset/FR-0030860_jpg.rf.b61e6bd271783a9060ac4be8bfe06030.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/non-vegetal-annotated-dataset/Non-Vegetal Annotated Dataset/FR-0030910_jpg.rf.c801c2e0d4a90647ced0a3d85b62f9ea.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/non-vegetal-annotated-dataset/Non-Vegetal Annotated Dataset/FR-0030818_jpg.rf.f7503b0590ffd651be28bee47e4e410f.xml': Read-only file system
# mv: cannot remove '/kaggle/input/non-vegetal-annotated-dataset/Non-Vegetal Annotated Dataset/FR-0030851_jpg.rf.261c1cfa33d1f6c900ce18046f5a23d8.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/non-vegetal-annotated-dataset/Non-Vegetal Annotated Dataset/FR-0030852_jpg.rf.60b970ee0800bf4d2e56819bcb43238b.xml': Read-only file system
# mv: cannot remove '/kaggle/input/non-vegetal-annotated-dataset/Non-Vegetal Annotated Dataset/FR-0036383_jpg.rf.10700be5ff0a418821a4973672e37b6d.jpg': Read-only file system

# %%
# !cat /kaggle/working/Dataset/FR-0036383_jpg.rf.10700be5ff0a418821a4973672e37b6d.xml
# import xml.etree.ElementTree as ET

# # Specify the path to your XML file
# xml_file_path = '/kaggle/working/Annotations/FR-0036395.xml'

# # Parse the XML file
# tree = ET.parse(xml_file_path)
# root = tree.getroot()

# # Access specific elements and attributes based on your XML structure
# for object_elem in root.findall('object'):
#     # Extract class label
#     class_label = object_elem.find('name').text
    
#     # Extract bounding box coordinates
#     bbox = object_elem.find('bndbox')
#     xmin = int(bbox.find('xmin').text)
#     ymin = int(bbox.find('ymin').text)
#     xmax = int(bbox.find('xmax').text)
#     ymax = int(bbox.find('ymax').text)
    
#     print(f"Class: {class_label}, Bounding Box: {xmin}, {ymin}, {xmax}, {ymax}")
# Out:
# <annotation>
# 	<folder></folder>
# 	<filename>FR-0036383_jpg.rf.10700be5ff0a418821a4973672e37b6d.jpg</filename>
# 	<path>FR-0036383_jpg.rf.10700be5ff0a418821a4973672e37b6d.jpg</path>
# 	<source>
# 		<database>roboflow.com</database>
# 	</source>
# 	<size>
# 		<width>640</width>
# 		<height>640</height>
# 		<depth>3</depth>
# 	</size>
# 	<segmented>0</segmented>
# 	<object>
# 		<name>barcode</name>
# 		<pose>Unspecified</pose>
# 		<truncated>0</truncated>
# 		<difficult>0</difficult>
# 		<occluded>0</occluded>
# 		<bndbox>
# 			<xmin>582</xmin>
# 			<xmax>641</xmax>
# 			<ymin>448</ymin>
# 			<ymax>634</ymax>
# 		</bndbox>
# 	</object>
# 	<object>
# 		<name>colors</name>
# 		<pose>Unspecified</pose>
# 		<truncated>0</truncated>
# 		<difficult>0</difficult>
# 		<occluded>0</occluded>
# 		<bndbox>
# 			<xmin>412</xmin>
# 			<xmax>554</xmax>
# 			<ymin>1</ymin>
# 			<ymax>141</ymax>
# 		</bndbox>
# 	</object>
# 	<object>
# 		<name>notes</name>
# 		<pose>Unspecified</pose>
# 		<truncated>0</truncated>
# 		<difficult>0</difficult>
# 		<occluded>0</occluded>
# 		<bndbox>
# 			<xmin>79</xmin>
# 			<xmax>135</xmax>
# 			<ymin>123</ymin>
# 			<ymax>329</ymax>
# 		</bndbox>
# 	</object>
# 	<object>
# 		<name>label</name>
# 		<pose>Unspecified</pose>
# 		<truncated>0</truncated>
# 		<difficult>0</difficult>
# 		<occluded>0</occluded>
# 		<bndbox>
# 			<xmin>42</xmin>
# 			<xmax>77</xmax>
# 			<ymin>170</ymin>
# 			<ymax>356</ymax>
# 		</bndbox>
# 	</object>
# 	<object>
# 		<name>notes</name>
# 		<pose>Unspecified</pose>
# 		<truncated>0</truncated>
# 		<difficult>0</difficult>
# 		<occluded>0</occluded>
# 		<bndbox>
# 			<xmin>1</xmin>
# 			<xmax>39</xmax>
# 			<ymin>1</ymin>
# 			<ymax>323</ymax>
# 		</bndbox>
# 	</object>
# 	<object>
# 		<name>scale</name>
# 		<pose>Unspecified</pose>
# 		<truncated>0</truncated>
# 		<difficult>0</difficult>
# 		<occluded>0</occluded>
# 		<bndbox>
# 			<xmin>122</xmin>
# 			<xmax>369</xmax>
# 			<ymin>583</ymin>
# 			<ymax>640</ymax>
# 		</bndbox>
# 	</object>
# </annotation>

# %%
import os
import xml.etree.ElementTree as ET

# Directory containing XML annotation files
xml_dir ="/kaggle/working/Dataset"

# Initialize class_name_to_id_mapping
class_name_to_id_mapping = {"scale": 0, "label": 0, "notes": 0, "colors": 0, "barcode": 0}

# Iterate through each XML file in the directory
for filename in os.listdir(xml_dir):
    if filename.endswith(".xml"):
        xml_path = os.path.join(xml_dir, filename)

        # Parse XML annotations
        tree = ET.parse(xml_path)
        root = tree.getroot()

        # Iterate through objects in the XML file
        for obj in root.findall('.//object'):
            label = obj.find('name').text

            # Check if the label is in the mapping
            if label in class_name_to_id_mapping:
                # Increment the count for the corresponding class
                class_name_to_id_mapping[label] += 1

# Print the resulting mapping
import matplotlib.pyplot as plt

# Assuming you already have class_name_to_id_mapping populated

# Extract class names and counts
class_names = list(class_name_to_id_mapping.keys())
class_counts = list(class_name_to_id_mapping.values())

# Calculate percentages
total_count = sum(class_counts)
class_percentages = [count / total_count * 100 for count in class_counts]

# Plot the bar plot with percentages
fig, ax = plt.subplots()
bars = ax.bar(class_names, class_counts, color='skyblue')

# Annotate the bars with percentages
for bar, percentage in zip(bars, class_percentages):
    height = bar.get_height()
    ax.annotate(f'{percentage:.2f}%', xy=(bar.get_x() + bar.get_width() / 2, height),
                xytext=(0, 3),  # 3 points vertical offset
                textcoords='offset points',
                ha='center', va='bottom')

plt.xlabel('Class Names')
plt.ylabel('Count')
plt.title('Percentage of Occurrences for Each Class')
plt.show()

# %%
# import os
# from collections import Counter
# import matplotlib.pyplot as plt

# def calculate_label_percentage_for_folder(folder_path):
#     # List all files in the folder with a .txt extension
#     txt_files = [f for f in os.listdir(folder_path) if f.endswith('.xml')]

#     # Accumulate label_class occurrences across all files
#     all_label_classes = []

#     for file_name in txt_files:
#         file_path = os.path.join(folder_path, file_name)

#         # Read the content of the file
#         with open(file_path, 'r') as file:
#             lines = file.readlines()

#         # Extract label_class from each line
#         label_classes = [int(line.split()[0]) for line in lines]
#         all_label_classes.extend(label_classes)

#     # Count occurrences of each label_class across all files
#     label_counts = Counter(all_label_classes)

#     # Calculate percentages
#     total_samples = len(all_label_classes)
#     percentages = {label: count / total_samples * 100 for label, count in label_counts.items()}

#     return percentages

# def plot_label_percentages(label_percentages):
#     labels, values = zip(*label_percentages.items())

#     plt.bar(labels, values)
#     plt.xlabel('Label Class')
#     plt.ylabel('Percentage')
#     plt.title('Label Class Percentages')

#     # Add labels to each bar
#     for label, value in zip(labels, values):
#         plt.text(label, value, f'{value:.2f}%', ha='center', va='bottom')

#     plt.show()

# if __name__ == "__main__":
#     # Specify the path to your folder
#     folder_path = "/kaggle/working/Dataset"

#     # Calculate label percentages for the entire folder
#     label_percentages = calculate_label_percentage_for_folder(folder_path)

#     # Print or save the results
#     print(f"Label percentages for the entire folder: {label_percentages}")

#     # Plot the label percentages with labels
# #     plot_label_percentages(label_percentages)

# %%
import os
import xml.etree.ElementTree as ET

# Directory containing XML annotation files
xml_dir ="/kaggle/working/Dataset"

# Initialize class_name_to_id_mapping
class_name_to_id_mapping = {"scale": 0, "label": 0, "notes": 0, "colors": 0, "barcode": 0}

# Iterate through each XML file in the directory
for filename in os.listdir(xml_dir):
    if filename.endswith(".xml"):
        xml_path = os.path.join(xml_dir, filename)

        # Parse XML annotations
        tree = ET.parse(xml_path)
        root = tree.getroot()

        # Iterate through objects in the XML file
        for obj in root.findall('.//object'):
            label = obj.find('name').text

            # Check if the label is in the mapping
            if label in class_name_to_id_mapping:
                # Increment the count for the corresponding class
                class_name_to_id_mapping[label] += 1

# Print the resulting mapping
import matplotlib.pyplot as plt

# Assuming you already have class_name_to_id_mapping populated

# Extract class names and counts
class_names = list(class_name_to_id_mapping.keys())
class_counts = list(class_name_to_id_mapping.values())

# Calculate percentages
total_count = sum(class_counts)
class_percentages = [count / total_count * 100 for count in class_counts]

# Plot the bar plot with percentages
fig, ax = plt.subplots()
bars = ax.bar(class_names, class_counts, color='skyblue')

# Annotate the bars with percentages
for bar, percentage in zip(bars, class_counts):
    height = bar.get_height()
    ax.annotate(f'{percentage}', xy=(bar.get_x() + bar.get_width() / 2, height),
                xytext=(0, 3),  # 3 points vertical offset
                textcoords='offset points',
                ha='center', va='bottom')

plt.xlabel('Class Names')
plt.ylabel('Count')
plt.title('Percentage of Occurrences for Each Class')
plt.show()

# %%
class_counts
# Out:
# [534, 229, 1241, 566, 505]

# %%
# Pip install method (recommended)

# !pip install ultralytics==8.0.20

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.0.0 CUDA:0 (Tesla P100-PCIE-16GB, 16276MiB)
# Setup complete ✅ (4 CPUs, 31.4 GB RAM, 5310.5/8062.4 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
# Function to get the data from XML Annotation

import xml.etree.ElementTree as ET
import cv2
import numpy as np

def extract_info_from_xml(xml_file):
    root = ET.parse(xml_file).getroot()
    
    # Initialise the info dict 
    info_dict = {}
    info_dict['bboxes'] = []

    # Parse the XML Tree
    for elem in root:
        # Get the file name 
        if elem.tag == "filename":
            info_dict['filename'] = elem.text
            
        # Get the image size
        elif elem.tag == "size":
            image_size = []
            for subelem in elem:
                image_size.append(int(subelem.text))
            
            info_dict['image_size'] = tuple(image_size)
        
        # Get details of the bounding box 
        elif elem.tag == "object":
            bbox = {}
            for subelem in elem:
                if subelem.tag == "name":
                    bbox["class"] = subelem.text
                    
                elif subelem.tag == "bndbox":
                    for subsubelem in subelem:
                        bbox[subsubelem.tag] = int(subsubelem.text)            
            info_dict['bboxes'].append(bbox)
    
    return info_dict

# %%
print(extract_info_from_xml('/kaggle/working/Dataset/FR-0036383_jpg.rf.10700be5ff0a418821a4973672e37b6d.xml'))
# Out:
# {'bboxes': [{'class': 'barcode', 'xmin': 582, 'xmax': 641, 'ymin': 448, 'ymax': 634}, {'class': 'colors', 'xmin': 412, 'xmax': 554, 'ymin': 1, 'ymax': 141}, {'class': 'notes', 'xmin': 79, 'xmax': 135, 'ymin': 123, 'ymax': 329}, {'class': 'label', 'xmin': 42, 'xmax': 77, 'ymin': 170, 'ymax': 356}, {'class': 'notes', 'xmin': 1, 'xmax': 39, 'ymin': 1, 'ymax': 323}, {'class': 'scale', 'xmin': 122, 'xmax': 369, 'ymin': 583, 'ymax': 640}], 'filename': 'FR-0036383_jpg.rf.10700be5ff0a418821a4973672e37b6d.jpg', 'image_size': (640, 640, 3)}

# %%
# Dictionary that maps class names to IDs
class_name_to_id_mapping = {"scale": 0, "label": 1, "notes": 2, "colors": 3, "barcode": 4}


# Convert the info dict to the required yolo format and write it to disk
def convert_to_yolov5(info_dict):
    print_buffer = []
    
    # For each bounding box
    for b in info_dict["bboxes"]:
        try:
            class_id = class_name_to_id_mapping[b["class"]]
        except KeyError:
            print("Invalid Class. Must be one from ", class_name_to_id_mapping.keys())
        
        # Transform the bbox co-ordinates as per the format required by YOLO v5
        b_center_x = (b["xmin"] + b["xmax"]) / 2 
        b_center_y = (b["ymin"] + b["ymax"]) / 2
        b_width    = (b["xmax"] - b["xmin"])
        b_height   = (b["ymax"] - b["ymin"])
        
        # Normalise the co-ordinates by the dimensions of the image
        image_w, image_h, image_c = info_dict["image_size"]  
        b_center_x /= image_w 
        b_center_y /= image_h 
        b_width    /= image_w 
        b_height   /= image_h 
        
        #Write the bbox details to the file 
        print_buffer.append("{} {:.3f} {:.3f} {:.3f} {:.3f}".format(class_id, b_center_x, b_center_y, b_width, b_height))
        
    # Name of the file which we have to save 
    save_file_name = os.path.join("/kaggle/working/Dataset/", info_dict["filename"].replace(".jpg", ".txt"))
    
    # Save the annotation to disk
    print("\n".join(print_buffer), file= open(save_file_name, "w"))

# %%
import torch
from IPython.display import Image  # for displaying images
import os 
import random
import shutil
from sklearn.model_selection import train_test_split
import xml.etree.ElementTree as ET
from xml.dom import minidom
from tqdm import tqdm
from PIL import Image, ImageDraw
import numpy as np
import matplotlib.pyplot as plt

random.seed(108)
# Get the annotations
annotations = [os.path.join('/kaggle/working/Dataset/', x) for x in os.listdir('/kaggle/working/Dataset/') if x[-3:] == "xml"]
annotations.sort()

# Convert and save the annotations
for ann in tqdm(annotations):
    info_dict = extract_info_from_xml(ann)
    convert_to_yolov5(info_dict)
annotations = [os.path.join('/kaggle/working/Dataset/', x) for x in os.listdir('/kaggle/working/Dataset/') if x[-3:] == "txt"]
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# 100%|██████████| 609/609 [00:00<00:00, 4201.47it/s]

# %%
import os 
import random
import shutil
from sklearn.model_selection import train_test_split
from tqdm import tqdm

# Read images and annotations
images = [os.path.join('/kaggle/working/Dataset', x) for x in os.listdir('/kaggle/working/Dataset/')if x[-3:] == "jpg"]
annotations = [os.path.join("/kaggle/working/Dataset/", x) for x in os.listdir('/kaggle/working/Dataset/') if x[-3:] == "txt"]

images.sort()
annotations.sort()

# Split the dataset into train-valid-test splits 
train_images, val_images, train_annotations, val_annotations = train_test_split(images, annotations, test_size = 0.2, random_state = 1)
val_images, test_images, val_annotations, test_annotations = train_test_split(val_images, val_annotations, test_size = 0.5, random_state = 1)

# %%
# !cat /kaggle/working/Dataset/FR-0030893_txt.rf.71045df440eb85c2342d145cfa3d8406.txt
# Out:
# cat: /kaggle/working/Dataset/FR-0030893_txt.rf.71045df440eb85c2342d145cfa3d8406.txt: No such file or directory

# %%
os.mkdir('train')
os.mkdir('train/images')
os.mkdir('train/labels')

os.mkdir('validation')
os.mkdir('validation/images')
os.mkdir('validation/labels')



os.mkdir('test')
os.mkdir('test/images')
os.mkdir('test/labels')

# %%
#Utility function to move images 
def move_files_to_folder(list_of_files, destination_folder):
    for f in list_of_files:
        try:
            shutil.move(f, destination_folder)
        except:
            assert False

# Move the splits into their folders
move_files_to_folder(train_images, '/kaggle/working/train/images')
move_files_to_folder(val_images, '/kaggle/working/validation/images/')
move_files_to_folder(test_images, '/kaggle/working/test/images/')
move_files_to_folder(train_annotations, '/kaggle/working/train/labels/')
move_files_to_folder(val_annotations, '/kaggle/working/validation/labels/')
move_files_to_folder(test_annotations, '/kaggle/working/test/labels/')

# %%
# import shutil

# src_path = r"/kaggle/input/dataset/data.yaml"
# dst_path = r"/kaggle/working/"
# shutil.copy(src_path, dst_path)
# print('Copied')

# %%
# !pwd
# Out:
# /kaggle/working

# %%
text = """
names: ['scale','label','notes','colors','barcode']
nc: 5

train: /kaggle/working/train/
val: /kaggle/working/validation/
test : /kaggle/working/test/


focal_loss: 1
counters_per_class: 534, 229, 1241, 566, 505
"""
with open("data.yaml", 'w') as file:
    file.write(text)

# %%
# !pwd
# Out:
# /kaggle/working

# %%
# !cat data.yaml
# Out:
# names: ['scale','label','notes','colors','barcode']
# nc: 5
#
# train: /kaggle/working/train/
# val: /kaggle/working/validation/
# test : /kaggle/working/test/
#
#
# focal_loss: 1
# counters_per_class: 534, 229, 1241, 566, 505

# %%
from ultralytics import YOLO

# Load a pretrained YOLOv8n model
model = YOLO('yolov8n.pt')  # build from YAML and transfer weights
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v0.0.0/yolov8n.pt to yolov8n.pt...
# 100%|██████████| 6.23M/6.23M [00:00<00:00, 73.8MB/s]

# %%
results = model.train(data="data.yaml", 
      name = 'licence_plate', epochs=100,batch = 24, 
      cache = True, iou = 0.45,
      augment=True, lr0=0.001, optimizer='Adam')
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.0.0 CUDA:0 (Tesla P100-PCIE-16GB, 16276MiB)
# yolo/engine/trainer: task=detect, mode=train, model=yolov8n.yaml, data=data.yaml, epochs=100, patience=50, batch=24, imgsz=640, save=True, cache=True, device=, workers=8, project=None, name=licence_plate, exist_ok=False, pretrained=False, optimizer=Adam, verbose=False, seed=0, deterministic=True, single_cls=False, image_weights=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, overlap_mask=True, mask_ratio=4, dropout=False, val=True, save_json=False, save_hybrid=False, conf=0.001, iou=0.45, max_det=300, half=False, dnn=False, plots=True, source=ultralytics/assets/, show=False, save_txt=False, save_conf=False, save_crop=False, hide_labels=False, hide_conf=False, vid_stride=1, line_thickness=3, visualize=False, augment=True, agnostic_nms=False, classes=None, retina_masks=False, boxes=True, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=17, workspace=4, nms=False, lr0=0.001, lrf=0.01, momentum=0.937, weight_decay=0.001, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, fl_gamma=0.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0, cfg=None, v5loader=False, save_dir=runs/detect/licence_plate
# Downloading https://ultralytics.com/assets/Arial.ttf to /root/.config/Ultralytics/Arial.ttf...
# 100%|██████████| 755k/755k [00:00<00:00, 14.9MB/s]
# Overriding model.yaml nc=80 with nc=5
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.Conv                  [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.Conv                  [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.C2f                   [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.Conv                  [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.C2f                   [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.Conv                  [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.C2f                   [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.Conv                  [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.C2f                   [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.SPPF                  [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.Concat                [1]
#  12                  -1  1    148224  ultralytics.nn.modules.C2f                   [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.Concat                [1]
#  15                  -1  1     37248  ultralytics.nn.modules.C2f                   [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.Conv                  [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.Concat                [1]
#  18                  -1  1    123648  ultralytics.nn.modules.C2f                   [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.Conv                  [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.Concat                [1]
#  21                  -1  1    493056  ultralytics.nn.modules.C2f                   [384, 256, 1]
#  22        [15, 18, 21]  1    752287  ultralytics.nn.modules.Detect                [5, [64, 128, 256]]
# Model summary: 225 layers, 3011823 parameters, 3011807 gradients, 8.2 GFLOPs
#
# Transferred 319/355 items from pretrained weights
# optimizer: Adam(lr=0.001) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0011250000000000001), 63 bias
# train: Scanning /kaggle/working/train/labels... 487 images, 14 backgrounds, 0 corrupt: 100%|██████████| 487/487 [00:00<00:00, 1261.60it/s]
# train: New cache created: /kaggle/working/train/labels.cache
# train: Caching images (0.6GB True): 100%|██████████| 487/487 [00:01<00:00, 471.48it/s]
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# val: Scanning /kaggle/working/validation/labels... 61 images, 0 backgrounds, 0 corrupt: 100%|██████████| 61/61 [00:00<00:00, 1232.59it/s]
# val: New cache created: /kaggle/working/validation/labels.cache
# val: Caching images (0.1GB True): 100%|██████████| 61/61 [00:00<00:00, 461.97it/s]
# Image sizes 640 train, 640 val
# Using 4 dataloader workers
# Logging results to runs/detect/licence_plate
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/100      4.53G      1.005      2.882      1.101         44        640: 100%|██████████| 21/21 [00:11<00:00,  1.88it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:02<00:00,  1.19s/it]
#                    all         61        309     0.0134       0.75      0.351      0.283
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/100      4.93G     0.9747      1.572      1.062         49        640: 100%|██████████| 21/21 [00:06<00:00,  3.07it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:01<00:00,  1.93it/s]
#                    all         61        309      0.863      0.335      0.659      0.476
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/100      4.93G     0.9222      1.223      1.051         43        640: 100%|██████████| 21/21 [00:06<00:00,  3.13it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:01<00:00,  1.96it/s]
#                    all         61        309      0.705      0.546      0.666      0.482
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/100      4.93G     0.9063      1.103      1.048         40        640: 100%|██████████| 21/21 [00:06<00:00,  3.14it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00,  2.06it/s]
#                    all         61        309      0.796      0.607      0.807      0.625
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/100      4.93G      0.887      1.024       1.05         46        640: 100%|██████████| 21/21 [00:06<00:00,  3.18it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00,  2.10it/s]
#                    all         61        309       0.85      0.829      0.851       0.64
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/100      4.93G     0.8919      1.019      1.047         50        640: 100%|██████████| 21/21 [00:06<00:00,  3.08it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00,  2.13it/s]
#                    all         61        
00:00,  3.17it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00,  2.09it/s]
#                    all         61        309      0.943      0.906      0.947      0.826
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      91/100      5.75G     0.5424     0.4364      0.931         33        640: 100%|██████████| 21/21 [00:07<00:00,  2.66it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00,  2.03it/s]
#                    all         61        309       0.94      0.916      0.954      0.823
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      92/100      5.75G     0.5429     0.4301     0.9331         30        640: 100%|██████████| 21/21 [00:06<00:00,  3.28it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00,  2.07it/s]
#                    all         61        309      0.918      0.936      0.949      0.819
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      93/100      5.75G     0.5259     0.4219     0.9167         36        640: 100%|██████████| 21/21 [00:06<00:00,  3.47it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00,  2.10it/s]
#                    all         61        309      0.916      0.946      0.949      0.815
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      94/100      5.75G     0.5317     0.4053     0.9225         24        640: 100%|██████████| 21/21 [00:06<00:00,  3.29it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00,  2.08it/s]
#                    all         61        309      0.926      0.936      0.953       0.82
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      95/100      5.75G     0.4977     0.3818     0.8957         25        640: 100%|██████████| 21/21 [00:06<00:00,  3.40it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00,  2.12it/s]
#                    all         61        309      0.922      0.934      0.953      0.822
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      96/100      5.75G     0.5019     0.3839     0.9119         29        640: 100%|██████████| 21/21 [00:06<00:00,  3.46it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00,  2.08it/s]
#                    all         61        309      0.921      0.936       0.95      0.822
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      97/100      5.75G      0.504     0.3791     0.9147         31        640: 100%|██████████| 21/21 [00:06<00:00,  3.39it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00,  2.09it/s]
#                    all         61        309      0.932      0.933      0.955      0.819
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      98/100      5.75G     0.5116     0.3973       0.91         29        640: 100%|██████████| 21/21 [00:06<00:00,  3.34it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00,  2.07it/s]
#                    all         61        309      0.929      0.945      0.956      0.825
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      99/100      5.75G     0.4995     0.3771     0.9136         28        640: 100%|██████████| 21/21 [00:06<00:00,  3.23it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00,  2.16it/s]
#                    all         61        309       0.93      0.942      0.954      0.827
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     100/100      5.75G        0.5     0.3857     0.9128         31        640: 100%|██████████| 21/21 [00:06<00:00,  3.47it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:02<00:00,  1.45s/it]
#                    all         61        309      0.931      0.945      0.953      0.827
#
# 100 epochs completed in 0.240 hours.
# Optimizer stripped from runs/detect/licence_plate/weights/last.pt, 6.2MB
# Optimizer stripped from runs/detect/licence_plate/weights/best.pt, 6.2MB
#
# Validating runs/detect/licence_plate/weights/best.pt...
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.0.0 CUDA:0 (Tesla P100-PCIE-16GB, 16276MiB)
# Model summary (fused): 168 layers, 3006623 parameters, 0 gradients, 8.1 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:02<00:00,  1.43s/it]
#                    all         61        309      0.924      0.943      0.956      0.827
#                  scale         61         52      0.952          1       0.98      0.847
#                  label         61         26      0.888      0.911      0.945      0.781
#                  notes         61        129      0.879      0.853      0.907      0.714
#                 colors         61         56      0.963      0.982      0.985       0.93
#                barcode         61         46      0.937       0.97      0.964      0.864
# Speed: 1.9ms pre-process, 2.0ms inference, 0.0ms loss, 1.2ms post-process per image
# Results saved to runs/detect/licence_plate

# %%
# from IPython.display import FileLink
# FileLink(r'outputname1.tar.gz')
from IPython.display import display, Image
Image(filename="/kaggle/working/runs/detect/licence_plate/results.png", height=800)

# %%
print("GROUND TRUTH TRAINING DATA:")
Image(filename='/kaggle/working/runs/detect/licence_plate/train_batch1891.jpg', width=900)
# Out:
# GROUND TRUTH TRAINING DATA:

# %%
Image(filename='/kaggle/working/runs/detect/licence_plate/confusion_matrix.png', width=900)

# %%
# testing our model
# !yolo task=detect mode=val model=./runs/detect/licence_plate/weights/best.pt data=data.yaml conf=0.5
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.0.0 CUDA:0 (Tesla P100-PCIE-16GB, 16276MiB)
# Model summary (fused): 168 layers, 3006623 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /kaggle/working/validation/labels.cache... 61 images, 0 background
#                  Class     Images  Instances      Box(P          R      mAP50  mWARNING ⚠️ NMS time limit 1.300s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         61        309      0.933      0.869      0.909      0.804
#                  scale         61         52       0.96      0.923      0.942      0.841
#                  label         61         26      0.913      0.808      0.887      0.741
#                  notes         61        129      0.875      0.814      0.851      0.704
#                 colors         61         56      0.962      0.911      0.945      0.904
#                barcode         61         46      0.953      0.891       0.92      0.832
# Speed: 3.7ms pre-process, 17.3ms inference, 0.0ms loss, 41.2ms post-process per image

# %%
# displying ground truth on test data
Image(filename='/kaggle/working/runs/detect/val/val_batch2_pred.jpg', width=900)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[32], line 2
#       1 # displying ground truth on test data
# ----> 2 Image(filename='/kaggle/working/runs/detect/val3/val_batch2_pred.jpg', width=900)
#
# File /opt/conda/lib/python3.10/site-packages/IPython/core/display.py:970, in Image.__init__(self, data, url, filename, format, embed, width, height, retina, unconfined, metadata, alt)
#     968 self.unconfined = unconfined
#     969 self.alt = alt
# --> 970 super(Image, self).__init__(data=data, url=url, filename=filename,
#     971         metadata=metadata)
#     973 if self.width is None and self.metadata.get('width', {}):
#     974     self.width = metadata['width']
#
# File /opt/conda/lib/python3.10/site-packages/IPython/core/display.py:327, in DisplayObject.__init__(self, data, url, filename, metadata)
#     324 elif self.metadata is None:
#     325     self.metadata = {}
# --> 327 self.reload()
#     328 self._check_data()
#
# File /opt/conda/lib/python3.10/site-packages/IPython/core/display.py:1005, in Image.reload(self)
#    1003 """Reload the raw data from file or URL."""
#    1004 if self.embed:
# -> 1005     super(Image,self).reload()
#    1006     if self.retina:
#    1007         self._retina_shape()
#
# File /opt/conda/lib/python3.10/site-packages/IPython/core/display.py:353, in DisplayObject.reload(self)
#     351 if self.filename is not None:
#     352     encoding = None if "b" in self._read_flags else "utf-8"
# --> 353     with open(self.filename, self._read_flags, encoding=encoding) as f:
#     354         self.data = f.read()
#     355 elif self.url is not None:
#     356     # Deferred import
#
# FileNotFoundError: [Errno 2] No such file or directory: '/kaggle/working/runs/detect/val3/val_batch2_pred.jpg'
